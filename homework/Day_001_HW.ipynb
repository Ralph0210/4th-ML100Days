# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    
    mae = MAE = sum(abs(y-yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title('Assume we have data points')
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = "prediction")
plt.title('Assume we have data points (And the prediction)')
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print('The Mean absolute error is %.3f' % (MAE))
# Out:
# The Mean squared error is 211.007
# The Mean absolute error is 11.843

# %%
"""
hw2:

Novel Corona Virus 2019 Dataset
https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset

1. 你選的這組資料為何重要:此資料提供coronavirus病患之
a. serial number (easier for future reference) b. date and time of observation c.place of ovservation 
d. death toll (in each state or country) e. confirmed cases f.recovered cases 的數據。
此筆資料的完整性與橫跨時間、地域，應當能提供各級研究、醫護人員與AI計算出病毒擴散範圍、可能帶源者等。

2. 資料從何而來：Johns Hopkins university, WHO, CDC, NHC, DXY
3. 蒐集而來的資料型態為何:表格
4. 這組資料想解決的問題如何評估：此資料僅為一份空開資料供各類研究用途


"""

# %%
"""
hm3:
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1. 核心問題為:1.如何精準算出不同司機在不同路線出車時間，以及所在位置與各車油耗推算來推薦司機讓客人在最短時間內被接到 = 提升業績
2. 資料從何而來：google maps可提供車輛衛星定位、預計到達時間、實際到達時間與即時車流推估，車輛內建系統計算油耗
3. 蒐集而來的資料型態為何：數值、表格
4. 你要回答的問題，其如何評估：預計縮短客人叫車坐車時間與實際叫車坐車時間，MAE



"""
